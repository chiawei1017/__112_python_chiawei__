# %%
import numpy as np
import pandas as pd

scores = np.random.randint(40, high=101, size=(50,5))
scores_df = pd.DataFrame(scores,
    columns=['國文','英文','數學','地理','歷史'],
    index=range(1,51))    
scores_df.index.name = "學號"
scores_df.columns.name = "科目"
sum_series = scores_df.sum(axis=1)
mean_series = scores_df.mean(axis=1)
#display(sum_series)
rank_series = sum_series.rank(method='min',ascending=False)
scores_df["總分"]= sum_series
scores_df["平均"]= mean_series
scores_df["名次"]= rank_series
scores_df.sort_values(by='名次')
# Out:
# 科目  國文  英文   數學  地理   歷史   總分    平均    名次
# 學號
# 49  60  92   92  84  100  428  85.6   1.0
# 46  97  78   62  98   79  414  82.8   2.0
# 47  93  81   93  88   56  411  82.2   3.0
# 5   91  66   83  83   81  404  80.8   4.0
# 28  92  64   96  76   64  392  78.4   5.0
# 48  66  60   99  81   86  392  78.4   5.0
# 22  60  67   72  98   95  392  78.4   5.0
# 16  87  85   47  74   99  392  78.4   5.0
# 8   85  96   47  76   85  389  77.8   9.0
# 23  78  87   73  66   77  381  76.2  10.0
# 30  87  51   99  91   47  375  75.0  11.0
# 44  69  59   77  86   84  375  75.0  11.0
# 19  83  90   55  87   58  373  74.6  13.0
# 25  84  93   91  52   52  372  74.4  14.0
# 40  69  81   77  76   69  372  74.4  14.0
# 18  46  63  100  89   73  371  74.2  16.0
# 3   85  97   51  49   88  370  74.0  17.0
# 11  71  83   93  40   81  368  73.6  18.0
# 35  47  64   96  67   92  366  73.2  19.0
# 26  90  75   55  86   59  365  73.0  20.0
# 42  81  86   54  63   76  360  72.0  21.0
# 29  49  93   55  72   90  359  71.8  22.0
# 37  41  88   65  95   67  356  71.2  23.0
# 4   90  69   48  61   87  355  71.0  24.0
# 27  41  89   86  41   95  352  70.4  25.0
# 14  84  84   75  64   44  351  70.2  26.0
# 33  60  73   80  41   96  350  70.0  27.0
# 17  64  41   94  94   55  348  69.6  28.0
# 34  51  89   66  79   55  340  68.0  29.0
# 13  89  69   40  80   59  337  67.4  30.0
# 15  58  91   42  64   76  331  66.2  31.0
# 24  70  45   79  93   42  329  65.8  32.0
# 2   48  51   68  80   82  329  65.8  32.0
# 45  68  67   52  91   49  327  65.4  34.0
# 36  88  89   45  56   49  327  65.4  34.0
# 1   54  43   95  59   75  326  65.2  36.0
# 12  86  61   47  81   48  323  64.6  37.0
# 41  79  49   80  41   73  322  64.4  38.0
# 43  57  71   87  63   42  320  64.0  39.0
# 39  65  62   85  67   40  319  63.8  40.0
# 50  64  44   96  73   42  319  63.8  40.0
# 32  76  49   72  53   60  310  62.0  42.0
# 10  49  57   56  75   72  309  61.8  43.0
# 38  58  48   60  64   77  307  61.4  44.0
# 21  53  89   40  43   78  303  60.6  45.0
# 7   57  41   66  50   89  303  60.6  45.0
# 6   62  73   43  62   50  290  58.0  47.0
# 20  48  42   78  75   44  287  57.4  48.0
# 9   83  43   44  41   49  260  52.0  49.0
# 31  44  48   49  51   61  253  50.6  50.0
