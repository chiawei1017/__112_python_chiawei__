. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
import requests
import io

#url = 'https://service.taipower.com.tw/data/opendata/apply/file/d010004/%E6%9C%AC%E5%85%AC%E5%8F%B8%E5%9C%9F%E5%9C%B0%E5%87%BA%E7%A7%9F%E4%BD%9C%E9%9B%BB%E5%8B%95%E6%A9%9F%E8%BB%8A%E9%9B%BB%E6%B1%A0%E4%BA%A4%E6%8F%9B%E7%AB%99%E6%98%8E%E7%B4%B0%E8%A1%A8(%E6%96%B0).csv'
url = 'https://github.com/roberthsu2003/python/blob/master/%E6%AA%94%E6%A1%88%E5%AD%98%E5%8F%96/%E5%90%84%E9%84%89%E9%8E%AE%E5%B8%82%E5%8D%80%E4%BA%BA%E5%8F%A3%E5%AF%86%E5%BA%A6.csv'

r = requests.get(url)
file = io.StringIO(r.text)

# %%
import csv
csv_reader = csv.reader(file)
csv_list = list(csv_reader)
for item in csv_list:
    print(item)
# Out:
# ['{"payload":{"allShortcutsEnabled":false', 'fileTree:{"檔案存取":{"items":[{"name":".ipynb_checkpoints"', 'path:"檔案存取/.ipynb_checkpoints"', 'contentType:"directory"}', '{"name":"縣市長"', 'path:"檔案存取/縣市長"', 'contentType:"directory"}', '{"name":".DS_Store"', 'path:"檔案存取/.DS_Store"', 'contentType:"file"}', '{"name":"1d.png"', 'path:"檔案存取/1d.png"', 'contentType:"file"}', '{"name":"2d.png"', 'path:"檔案存取/2d.png"', 'contentType:"file"}', '{"name":"3d.png"', 'path:"檔案存取/3d.png"', 'contentType:"file"}', '{"name":"4d.png"', 'path:"檔案存取/4d.png"', 'contentType:"file"}', '{"name":"README.ipynb"', 'path:"檔案存取/README.ipynb"', 'contentType:"file"}', '{"name":"city.db"', 'path:"檔案存取/city.db"', 'contentType:"file"}', '{"name":"csvRead.ipynb"', 'path:"檔案存取/csvRead.ipynb"', 'contentType:"file"}', '{"name":"data.json"', 'path:"檔案存取/data.json"', 'contentType:"file"}', '{"name":"data.txt"', 'path:"檔案存取/data.txt"', 'contentType:"file"}', '{"name":"data1.txt"', 'path:"檔案存取/data1.txt"', 'contentType:"file"}', '{"name":"ex1.csv"', 'path:"檔案存取/ex1.csv"', 'contentType:"file"}', '{"name":"ex2.csv"', 'path:"檔案存取/ex2.csv"', 'contentType:"file"}', '{"name":"ex3.csv"', 'path:"檔案存取/ex3.csv"', 'contentType:"file"}', '{"name":"ex4.csv"', 'path:"檔案存取/ex4.csv"', 'contentType:"file"}', '{"name":"ex5.csv"', 'path:"檔案存取/ex5.csv"', 'contentType:"file"}', '{"name":"ex6.csv"', 'path:"檔案存取/ex6.csv"', 'contentType:"file"}', '{"name":"ex7.csv"', 'path:"檔案存取/ex7.csv"', 'contentType:"file"}', '{"name":"example.json"', 'path:"檔案存取/example.json"', 'contentType:"file"}', '{"name":"jsonReader.ipynb"', 'path:"檔案存取/jsonReader.ipynb"', 'contentType:"file"}', '{"name":"relativity"', 'path:"檔案存取/relativity"', 'contentType:"file"}', '{"name":"result-readlines.txt"', 'path:"檔案存取/result-readlines.txt"', 'contentType:"file"}', '{"name":"sample5.py"', 'path:"檔案存取/sample5.py"', 'contentType:"file"}', '{"name":"score.json"', 'path:"檔案存取/score.json"', 'contentType:"file"}', '{"name":"score.txt"', 'path:"檔案存取/score.txt"', 'contentType:"file"}', '{"name":"train.db"', 'path:"檔案存取/train.db"', 'contentType:"file"}', '{"name":"ttest.csv"', 'path:"檔案存取/ttest.csv"', 'contentType:"file"}', '{"name":"個股日成交資訊.csv"', 'path:"檔案存取/個股日成交資訊.csv"', 'contentType:"file"}', '{"name":"個股日成交資訊.ipynb"', 'path:"檔案存取/個股日成交資訊.ipynb"', 'contentType:"file"}', '{"name":"各鄉鎮市區人口密度.csv"', 'path:"檔案存取/各鄉鎮市區人口密度.csv"', 'contentType:"file"}', '{"name":"學習用範例來源檔.zip"', 'path:"檔案存取/學習用範例來源檔.zip"', 'contentType:"file"}', '{"name":"新北市公共自行車租賃系統.json"', 'path:"檔案存取/新北市公共自行車租賃系統.json"', 'contentType:"file"}', '{"name":"新北市食品工廠清冊.csv"', 'path:"檔案存取/新北市食品工廠清冊.csv"', 'contentType:"file"}', '{"name":"新北市食品工廠清冊.json"', 'path:"檔案存取/新北市食品工廠清冊.json"', 'contentType:"file"}', '{"name":"歷年國內主要觀光遊憩據點遊客人數月別統計.csv"', 'path:"檔案存取/歷年國內主要觀光遊憩據點遊客人數月別統計.csv"', 'contentType:"file"}]', 'totalCount:37}', ':{"items":[{"name":".devcontainer"', 'path:".devcontainer"', 'contentType:"directory"}', '{"name":"Concurrency"', 'path:"Concurrency"', 'contentType:"directory"}', '{"name":"TQC"', 'path:"TQC"', 'contentType:"directory"}', '{"name":"chat_gpt"', 'path:"chat_gpt"', 'contentType:"directory"}', '{"name":"line"', 'path:"line"', 'contentType:"directory"}', '{"name":"line_bot"', 'path:"line_bot"', 'contentType:"directory"}', '{"name":"python內建的資料結構"', 'path:"python內建的資料結構"', 'contentType:"directory"}', '{"name":"python型別提示"', 'path:"python型別提示"', 'contentType:"directory"}', '{"name":"python基礎與資料輸出"', 'path:"python基礎與資料輸出"', 'contentType:"directory"}', '{"name":"sqlalchemy_orm"', 'path:"sqlalchemy_orm"', 'contentType:"directory"}', '{"name":"上課用目錄"', 'path:"上課用目錄"', 'contentType:"directory"}', '{"name":"函式和comprehension"', 'path:"函式和comprehension"', 'contentType:"directory"}', '{"name":"匿名函數lambda"', 'path:"匿名函數lambda"', 'contentType:"directory"}', '{"name":"國發會驗收"', 'path:"國發會驗收"', 'contentType:"directory"}', '{"name":"字串處理"', 'path:"字串處理"', 'contentType:"directory"}', '{"name":"小程式"', 'path:"小程式"', 'contentType:"directory"}', '{"name":"數值與函數進階運用"', 'path:"數值與函數進 ...

# %%
import pandas as pd
df = pd.DataFrame(csv_list)
df
# Out:
#                                       0     \
# 0  {"payload":{"allShortcutsEnabled":false
#
#                                                 1     \
# 0  fileTree:{"檔案存取":{"items":[{"name":".ipynb_che...
#
#                              2                         3              4     \
# 0  path:"檔案存取/.ipynb_checkpoints"  contentType:"directory"}  {"name":"縣市長"
#
#               5                         6                    7     \
# 0  path:"檔案存取/縣市長"  contentType:"directory"}  {"name":".DS_Store"
#
#                     8                    9     ...           2187  \
# 0  path:"檔案存取/.DS_Store"  contentType:"file"}  ...  viewable:true
#
#                        2188                       2189              2190  \
# 0  workflowRedirectUrl:null  symbols:{"timedOut":false  notAnalyzed:true
#
#            2191              2192                        2193  \
# 0  symbols:[]}}  copilotInfo:null  copilotAccessAllowed:false
#
#                                                 2194  \
# 0  csrf_tokens:{"/roberthsu2003/python/branches":...
#
#                                                 2195  \
# 0  /repos/preferences:{"post":"x4KdaZSnuQ-Z7gQf2r...
#
#                                                 2196
# 0  title:"python/檔案存取/各鄉鎮市區人口密度.csv at master · r...
#
# [1 rows x 2197 columns]
